# %%
import pandas as pd

# Load your Titanic dataset from your local machine
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# Display the column names
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df.shape
# Out:
# (891, 15)

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df.groupby("sex")["age"].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/KeithGalli/pandas/master/pokemon_data.csv"
df = pd.read_csv(url, encoding='ISO-8859-1')
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
df.groupby('Type 1')['Attack'].describe()
# Out:
#           count        mean        std   min    25%    50%     75%    max
# Type 1
# Bug        69.0   70.971014  37.040904  10.0  45.00   65.0   90.00  185.0
# Dark       31.0   88.387097  25.774247  50.0  65.00   88.0  100.00  150.0
# Dragon     32.0  112.125000  33.742622  50.0  86.25  113.5  134.25  180.0
# Electric   44.0   69.090909  23.764169  30.0  53.75   65.0   85.00  123.0
# Fairy      17.0   61.529412  29.751298  20.0  45.00   52.0   72.00  131.0
# Fighting   27.0   96.777778  28.290163  35.0  80.00  100.0  120.00  145.0
# Fire       52.0   84.769231  28.769275  30.0  62.25   84.5  101.00  160.0
# Flying      4.0   78.750000  37.500000  30.0  60.00   85.0  103.75  115.0
# Ghost      32.0   73.781250  29.629687  30.0  53.75   66.0   92.75  165.0
# Grass      70.0   73.214286  25.380520  27.0  55.00   70.0   93.50  132.0
# Ground     32.0   95.750000  33.059087  40.0  72.00   85.0  121.00  180.0
# Ice        24.0   72.750000  27.289511  30.0  50.00   67.0   87.50  130.0
# ...

# %% [markdown]
# df.groupby('col1')['col2'].describe() means first step is to devide the all the data that have the same value of column 1 in to same group. Next, we use the function .describe() to calculate the attack value of different types Pokeaman.

# %% [markdown]
# Transcript with Chatgpt--https://chatgpt.com/c/66e1d905-c248-800a-b9ad-4a6414ee314e

# %% [markdown]
# Q2

# %% [markdown]
# df.describe() is a overview of all the data is each column for whole dataset, while df.groupby('col1')['col2'].describe() only calculate certain column of data after being grouped.

# %% [markdown]
# Transcript with Chatgpt--https://chatgpt.com/c/66e1d905-c248-800a-b9ad-4a6414ee314e

# %% [markdown]
# Q3-A

# %%
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# Display the column names
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')
#       3 # Display the column names
#       4 print(df.columns)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# Display the column names
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanics.csv')

# Display the column names
print(df.columns)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanics.csv')
#       4 # Display the column names
#       5 print(df.columns)
#
# ...

# %%
import pandas as pd

# Correct URL for the Titanic dataset
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv')

# Display the column names
print(df.columns)
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
DF.groupby('sex')['age'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 DF.groupby('sex')['age'].describe()
#
# NameError: name 'DF' is not defined

# %%
import pandas as pd

# Correct URL for the Titanic dataset
df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'

# Display the column names
print(df.columns)
# Out:
#   Cell In[7], line 4
#     df = pd.read_csv('https://raw.githubusercontent.com/mwaskom/seaborn-data/master/titanic.csv'
#                     ^
# SyntaxError: '(' was never closed

# %%
df.group_by('sex')['age'].describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_102/1659428212.py in ?()
# ----> 1 df.group_by('sex')['age'].describe()
#
# /opt/conda/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'group_by'

# %%
df.groupby('Sex')['age'].describe()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.groupby('Sex')['age'].describe()
#
# File /opt/conda/lib/python3.11/site-packages/pandas/core/frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# ...

# %%
df.groupby(sex)["age"].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.groupby(sex)["age"].describe()
#
# NameError: name 'sex' is not defined

# %% [markdown]
# I think use ChatBot to correct the error is much easier than using google.

# %% [markdown]
# Transcript with Chatgpt--https://chatgpt.com/c/66e1d905-c248-800a-b9ad-4a6414ee314e
